# %% [markdown]
# <a href="https://www.kaggle.com/muhammadosamasaleem/h-m-data-analysis?scriptVersionId=86873790" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Loading Dataset

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/hm-stores-dataset/HM_all_stores.csv

# %% [markdown]
# ### Loading Dataset

# %%
df = pd.read_csv('../input/hm-stores-dataset/HM_all_stores.csv')
df.head(10)
# Out:
#   storeCode storeClass                            name          phone  \
# 0    AE0122        Red             Mirdiff city center  +971-42316646
# 1    AE0149   Flagship                      Dubai Mall  +971-44190346
# 2    AE0209       Blue                   Al Markaziyah  +971-26120870
# 3    AE0223       Blue  Abu Dhabi-Dubai Rd - Abu Dhabi  +971-26120851
# 4    AE0273   Flagship                        Yas Mall  +971-24926530
# 5    AE0412        Red                        Street E  +971-44190590
# 6    AE0420       Blue            Fujairah City Center  +971-92029601
# 7    AE0427        Red                   Al whada mall  +971-26958180
# 8    AE0428        Red                      Manar Mall  +971-72264925
# 9    AE0433   Flagship                           dubai  +971-43415440
#
#              city               country countryCode  longitude   latitude  \
# 0           Dubai  United Arab Emirates          AE  55.424840  25.226280
# ...

# %% [markdown]
# ### Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4292 entries, 0 to 4291
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   storeCode       4292 non-null   object
#  1   storeClass      4289 non-null   object
#  2   name            4290 non-null   object
#  3   phone           4140 non-null   object
#  4   city            4292 non-null   object
#  5   country         4292 non-null   object
#  6   countryCode     4292 non-null   object
#  7   longitude       4292 non-null   float64
#  8   latitude        4292 non-null   float64
#  9   timeZoneIndex   4289 non-null   float64
#  10  Mon_open_hours  4258 non-null   object
#  11  Tue_open_hours  4258 non-null   object
#  12  Wed_open_hours  4258 non-null   object
#  13  Thu_open_hours  4258 non-null   object
#  14  Fri_open_hours  4258 non-null   object
#  15  Sat_open_hours  4258 non-null   object
#  16  Sun_open_hours  3148 non-null   object
# ...

# %% [markdown]
# ### Countries in which store is present

# %%
unqCountries= df['country'].unique()

# %%
unqCountries
# Out:
# array(['United Arab Emirates', 'Austria', 'Australia',
#        'Bosnia and Herzegovina', 'Belgium', 'Bulgaria', 'Bahrain',
#        'Belarus', 'Canada', 'Switzerland', 'Chile', 'Mainland China',
#        'Colombia', 'Cyprus', 'Czech Republic', 'Germany', 'Denmark',
#        'Estonia', 'Egypt', 'Spain', 'Finland', 'France', 'UK', 'Georgia',
#        'Greece', 'Hong Kong SAR', 'Croatia', 'Hungary', 'Indonesia',
#        'Ireland', 'Israel', 'India', 'Iceland', 'Italy', 'Jordan',
#        'Japan', 'Korea, Republic of', 'Kuwait', 'Kazakhstan', 'Lebanon',
#        'Lithuania', 'Luxembourg', 'Latvia', 'Morocco', 'Macao SAR',
#        'Mexico', 'Malaysia', 'Netherlands', 'Norway', 'New Zealand',
#        'Oman', 'Panama', 'Peru', 'Philippines', 'Poland', 'USA',
#        'Portugal', 'Qatar', 'Romania', 'Serbia', 'Russian Federation',
#        'Saudi Arabia', 'Sweden', 'Singapore', 'Slovenia', 'Slovakia',
#        'Thailand', 'Tunisia', 'Turkey', 'Taiwan Region', 'Ukraine',
# ...

# %% [markdown]
# **Total number of countries in which store is present**

# %%
 df['country'].nunique()
# Out:
# 74

# %% [markdown]
# ### Total number of store in each country

# %%
pd.set_option('display.max_row',10) ## to view all replace 10 with None 
df['country'].value_counts()
# Out:
# USA                       532
# Mainland China            408
# Germany                   383
# UK                        215
# France                    186
#                          ...
# Bosnia and Herzegovina      2
# Lebanon                     2
# Cyprus                      1
# Macao SAR                   1
# Panama                      1
# Name: country, Length: 74, dtype: int64

# %% [markdown]
# ### Store Classes

# %%
df['storeClass'].unique()
# Out:
# array(['Red', 'Flagship', 'Blue', 'F', nan], dtype=object)

# %% [markdown]
# **Total number of classes**

# %%
df['storeClass'].nunique()
# Out:
# 4

# %% [markdown]
# ### Total cities in which H&M store is present

# %%
unq_city = df['city'].nunique()


unq_city
# Out:
# 2522

# %% [markdown]
# ### Counties, Cities and the number of store in respective city

# %%
pd.set_option('display.max_row',20) ## write None instead of 20 to view all
df[['city','country']].value_counts()
# Out:
# city                  country
# Moscow                Russian Federation    35
# Stockholm             Sweden                30
# Shanghai              Mainland China        28
# London                UK                    28
# Beijing               Mainland China        24
#                                             ..
# Lillestrøm            Norway                 1
# Lillehammer           Norway                 1
# Chalons en Champagne  France                 1
# Liezen                Austria                1
# A Coruña              Spain                  1
# Length: 2546, dtype: int64
